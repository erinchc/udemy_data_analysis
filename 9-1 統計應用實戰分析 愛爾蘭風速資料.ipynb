# %% [markdown]
# # 統計應用實戰分析
# ## 愛爾蘭風速資料
# 資料下載網址：https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data<br>
# Pandas read_csv : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html<br>
# 正規表示法：https://cheatography.com/davechild/cheat-sheets/regular-expressions/<br>
# Python 正規表示法模組re : https://docs.python.org/3/library/re.html

# %%
import pandas as pd
import datetime
#parse_dates[[0,1,2]]在匯入資料時會把欄位合併起來，變成一個單獨紀錄時間的欄位
data_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
data = pd.read_csv(data_url, sep = '\s+', parse_dates = [[0, 1, 2]])#sep='\s+'
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ## 修正日期錯誤
# * 資料的年份，從兩千開始補上前面的字元
# * 資料年份來到70時，又從19開始
#
# <br>修正方式:大於2060年的資料減去100，建立新的日期欄位資訊

# %%
def fix(x):
    year = x.year - 100 if x.year > 2060 else x.year
    return datetime.datetime(year, x.month, x.day)
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix)
data

# def fix(x):
#     if x.year>2060:
#         year=x.year-100
#     else:
#         year=x.year
#     return datetime.datetime(year, x.month, x.day)
# data['Yr_Mo_Dy']=data['Yr_Mo_Dy'].apply(fix)
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %% [markdown]
# ## 將日期欄位設定為index

# %%
data.index = pd.to_datetime(data['Yr_Mo_Dy'])
data
# Out:
#              Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# Yr_Mo_Dy
# 1961-01-01 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1961-01-02 1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 1961-01-03 1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 1961-01-04 1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 1961-01-05 1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 1978-12-28 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 1978-12-29 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 1978-12-30 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 1978-12-31 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
# ...

# %% [markdown]
# ## 取得每一個地區風速的統計資料，包含平均值、標準差等統計資訊

# %%
data.describe()
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6568.000000  6571.000000  6572.000000  6569.000000  6572.000000
# mean     12.362987    10.644314    11.660526     6.306468    10.455834
# std       5.618413     5.267356     5.008450     3.605811     4.936125
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     8.000000     3.580000     6.750000
# 50%      11.710000    10.170000    10.920000     5.750000     9.960000
# 75%      15.920000    14.040000    14.670000     8.420000    13.540000
# max      35.800000    33.370000    33.840000    28.460000    37.540000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6574.000000  6571.000000  6572.000000  6571.000000  6573.000000
# mean      7.092254     9.797343     8.495053     8.493590     8.707332
# std       3.968683     4.977555     4.499449     4.166872     4.503954
# ...
