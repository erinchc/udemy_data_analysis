# %% [markdown]
# # 實作股價K線圖
# 台積電 TSMC (2330) <br>
# 聯發科 MediaTek (2454)

# %%
import pandas as pd
import datetime as dt
import pandas_datareader as pdr

start = dt.datetime(2020, 1, 1)
end = dt.datetime(2020, 6, 1)
df_2330 = pdr.DataReader('2330.TW', 'yahoo', start=start, end=end)
df_2454 = pdr.DataReader('2454.TW', 'yahoo', start=start, end=end)
df_2330.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/pm/t7xh08q53hvbcx0zynj45_wr0000gn/T/ipykernel_10651/1330250971.py in <module>
#       5 start = dt.datetime(2020, 1, 1)
#       6 end = dt.datetime(2020, 6, 1)
# ----> 7 df_2330 = pdr.DataReader('2330.TW', 'yahoo', start=start, end=end)
#       8 df_2454 = pdr.DataReader('2454.TW', 'yahoo', start=start, end=end)
#       9 df_2330.head()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     368
#     369     if data_source == "yahoo":
# --> 370         return YahooDailyReader(
#     371             symbols=name,
#     372             start=start,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     151         try:
#     152             j = json.loads(re.search(ptrn, resp.text, re.DOTALL).group(1))
# --> 153             data = j["context"]["dispatcher"]["stores"]["HistoricalPriceStore"]
#     154         except KeyError:
#     155             msg = "No data fetched for symbol {} using {}"
#
# TypeError: string indices must be integers

# %% [markdown]
# ### 台積電 VS 聯發科 股價線圖

# %%
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

fig = plt.figure(figsize=(10, 6))
plt.plot(df_2330.Close, label='TSMC')
plt.plot(df_2454.Close, label='MediaTek')
plt.title('TSMC vs MediaTek', loc='center')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True, axis='y')
plt.legend()
plt.show()

# %% [markdown]
# ### 台積電股價K線圖
# 繪製股價圖表套件 mplfinance <br>
# Github 網址：https://github.com/matplotlib/mplfinance
